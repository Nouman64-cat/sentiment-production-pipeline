# %%
import pandas as pd

file_path_imdb = "imdb_sample_500.csv"
file_path_tweets = "tweets_sample_500.csv"

df_imdb = pd.read_csv(file_path_imdb)
df_tweets = pd.read_csv(file_path_tweets)

# %%
df_imdb.head()
# Out:
#                                               review  sentiment
# 0  amazing movie i saw this movie for the first t...          1
# 1  well i just paid a dollar for a dvd of this mo...          0
# 2  it is queen victorias misfortune to be defined...          1
# 3  it seems the makers of this film had trouble d...          0
# 4  the final film for ernst lubitsch, completed b...          0

# %%
df_tweets.head()
# Out:
#    target                                               text
# 0       1  is getting ready for a day outside. i should g...
# 1       0  i need a hug...and less cynicism. its making m...
# 2       1  mojitos are really good. hanging out with the ...
# 3       0          up since 300. going to be a looooong day.
# 4       0                                      naw are you!?

# %%
df_imdb = df_imdb.rename(columns={'review': 'text'})

df_imdb.head()
# Out:
#                                                 text  sentiment
# 0  amazing movie i saw this movie for the first t...          1
# 1  well i just paid a dollar for a dvd of this mo...          0
# 2  it is queen victorias misfortune to be defined...          1
# 3  it seems the makers of this film had trouble d...          0
# 4  the final film for ernst lubitsch, completed b...          0

# %%
df_tweets = df_tweets.rename(columns={'target': 'sentiment'})

df_tweets.head()
# Out:
#    sentiment                                               text
# 0          1  is getting ready for a day outside. i should g...
# 1          0  i need a hug...and less cynicism. its making m...
# 2          1  mojitos are really good. hanging out with the ...
# 3          0          up since 300. going to be a looooong day.
# 4          0                                      naw are you!?

# %%
df = pd.concat([df_imdb[['text', 'sentiment']], df_tweets[['text', 'sentiment']]])

df.head()
# Out:
#                                                 text  sentiment
# 0  amazing movie i saw this movie for the first t...          1
# 1  well i just paid a dollar for a dvd of this mo...          0
# 2  it is queen victorias misfortune to be defined...          1
# 3  it seems the makers of this film had trouble d...          0
# 4  the final film for ernst lubitsch, completed b...          0

# %%
print(df.value_counts())
# Out:
# text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
# ...

# %%
print(df.shape)
# Out:
# (1000, 2)

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df.head()
# Out:
#                                                 text  sentiment
# 0                       in fairness. he smells good.          1
# 1  i feel like im still in 7th grade. i hate this...          0
# 2  thanks so much i just really wanna hear his co...          1
# 3                  work sucks when your here all day          0
# 4  so theres an old security guard and a guy who ...          0

# %%
df.to_csv('data.csv', index=False)
